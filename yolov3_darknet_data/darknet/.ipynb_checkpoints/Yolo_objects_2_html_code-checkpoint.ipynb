# %%
# !rm yolo_predictions/*
# Out:
# rm: impossible de supprimer 'yolo_predictions/*': Aucun fichier ou dossier de ce type

# %%
import operator
def sort_yolo_objs_by_Top(_yolo_objs):
    #print(_yolo_objs.values())
    sorted_objs=sorted(_yolo_objs.items(), key=operator.itemgetter(0))
    #print(sorted_objs)
    return [x[1] for x in sorted_objs]
    
#test sort_yolo_objs_by_Top
sort_yolo_objs_by_Top({ 1:'paragraph',  6:'button',4:'textinput' ,7:'button'})
# Out:
# ['paragraph', 'textinput', 'button', 'button']

# %%
def build_html_from_obj(_type):
    if _type == 'header':
        return '<h1>HEADER</h1>'
        #return '<img src="https://kaleider.com/wp-content/uploads/2014/05/header2.jpg" width="700" height="100" alt="HEADER">'
    if _type == 'title':
        return '<h1>TITLE</h1>'
    elif _type == 'paragraph':
        return '<p style="margin-top: 10px;">Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.</p>'
    elif _type == 'textinput':
        return '<input type="text" class="form-control" style="margin-top: 10px;" placeholder="text">'
    elif _type == 'button':
        return '<button type="button" class="btn btn-primary" style="margin-top: 10px;">Button</button>'
    else:
        raise ValueError('non handled object type:<' + _type +'>'  )

#test build_html_from_obj function    
print(build_html_from_obj('textinput'))
# Out:
# <input type="text" class="form-control" style="margin-top: 10px;" placeholder="text">

# %%
from bs4 import BeautifulSoup as bs
def yolo_objects_2_code_factory(yolo_objects):
    sorted_objs=sort_yolo_objs_by_Top(yolo_objects)
    html_code='<head> <title>Page Generated from Computer Vision</title> <meta charset="utf-8"> <meta name="viewport" content="width=device-width, initial-scale=1"> <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/css/bootstrap.min.css"> <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js"></script> <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/js/bootstrap.min.js"></script> </head><body><div class="container">'
    for obj in sorted_objs:
        #print(obj)
        html_code=html_code+build_html_from_obj(obj)
    html_code=html_code+'</div></body></html>'
    return bs(html_code).prettify()
#test objects_2_code_factory  
print(yolo_objects_2_code_factory({ 0:'header',1:'title',  6:'paragraph',4:'textinput' ,7:'textinput',8:'button'}))
# Out:
# <html>
#  <head>
#   <title>
#    Page Generated from Computer Vision
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/css/bootstrap.min.css" rel="stylesheet"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js">
#   </script>
#   <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/js/bootstrap.min.js">
#   </script>
#  </head>
#  <body>
#   <div class="container">
#    <img alt="HEADER" height="100" src="https://kaleider.com/wp-content/uploads/2014/05/header2.jpg" width="700"/>
#    <h1>
#     TITLE
#    </h1>
#    <input class="form-control" placeholder="text" style="margin-top: 10px;" type="text"/>
#    <p style="margin-top: 10px;">
#     Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
#    </p>
#    <input class="form-control" placeholder="text" style="margin-top: 10px;" type="text"/>
#    <button class="btn btn-primary" style="margin-top: 10px;" type="button">
#     Button
#    </button>
#   </div>
#  </body>
# </html>

# %%
def read_objects_from_yolo_file(yolo_obs_file):
    myfile = open(yolo_obs_file)
    next(myfile)# to skip the first line
    yolo_detected_objs={}
    for line in myfile:
        _type=line.split(':')[0]
        _top=int(next(myfile).split(' ')[2].split(':')[1])
        yolo_detected_objs[_top]=_type
    myfile.close()
    return yolo_detected_objs

#test read_objects_from_yolo_file
read_objects_from_yolo_file('Yolo_files/predictions_3156.txt')
# Out:
# {249: 'title', 1182: 'textinput', 1870: 'button', 2451: 'textinput'}

# %%
print(yolo_objects_2_code_factory(read_objects_from_yolo_file('Yolo_files/predictions_3156.txt')))
# Out:
# <html>
#  <head>
#   <title>
#    Page Generated from Computer Vision
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/css/bootstrap.min.css" rel="stylesheet"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js">
#   </script>
#   <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.0/js/bootstrap.min.js">
#   </script>
#  </head>
#  <body>
#   <div class="container">
#    <h1>
#     TITLE
#    </h1>
#    <input class="form-control" placeholder="text" style="margin-top: 10px;" type="text"/>
#    <button class="btn btn-primary" style="margin-top: 10px;" type="button">
#     Button
#    </button>
#    <input class="form-control" placeholder="text" style="margin-top: 10px;" type="text"/>
#   </div>
#  </body>
# </html>

# %%
def write_html_code_from_yolo_prediction(html_page_path,yolo_prediction_file):
    f = open(html_page_path,'w')
    #2844,3103,3156
    f.write(yolo_objects_2_code_factory(read_objects_from_yolo_file(yolo_prediction_file)))
    f.close()
    #install browsify in your PC:  npm install -g browser-sync, then start a node server :browser-sync start --server -w index.html
    
#test write_html_code_from_yolo_prediction 
write_html_code_from_yolo_prediction('Yolo_output_code/index.html', 'Yolo_files/predictions_3156.txt')

# %%
import glob
import os
def get_last_prediction_file(yolo_prediction_folder):
    if(not glob.glob(yolo_prediction_folder)):
        return ''
    list_of_files = glob.glob(yolo_prediction_folder)
    latest_file = max(list_of_files, key=os.path.getmtime)
    return latest_file

#test get_last_prediction_file on folder 'C:/yolo_predictions/*'
get_last_prediction_file('yolo_predictions/*')
# Out:
# ''

# %%
import time
import cv2

def rewrite_html_each(sec):
    already_handled_file=None
    while True:
        last_prediction_intime=get_last_prediction_file('yolo_predictions/*')
        if(last_prediction_intime !='' and last_prediction_intime!=already_handled_file):
            print('already_handled_file:'+ str(already_handled_file))
            write_html_code_from_yolo_prediction('Yolo_output_code/index.html',last_prediction_intime)
        time.sleep(sec)
        already_handled_file=last_prediction_intime

rewrite_html_each(1)

#In a command prompt : ./darknet detector demoi darknet.data yolov3-tiny-data.cfg weights/yolov3-tiny-data_final.weights
# Out:
# already_handled_file:
# already_handled_file:yolo_predictions/output0.txt
# already_handled_file:yolo_predictions/output1.txt
# already_handled_file:yolo_predictions/output2.txt
# already_handled_file:yolo_predictions/output3.txt
# already_handled_file:yolo_predictions/output4.txt
# already_handled_file:yolo_predictions/output5.txt
# already_handled_file:yolo_predictions/output6.txt
# already_handled_file:yolo_predictions/output7.txt
# already_handled_file:yolo_predictions/output8.txt
# already_handled_file:yolo_predictions/output9.txt
# already_handled_file:yolo_predictions/output10.txt
# already_handled_file:yolo_predictions/output11.txt
# already_handled_file:yolo_predictions/output12.txt
# already_handled_file:yolo_predictions/output13.txt
# already_handled_file:yolo_predictions/output14.txt
# already_handled_file:yolo_predictions/output15.txt
# already_handled_file:yolo_predictions/output16.txt
# already_handled_file:yolo_predictions/output17.txt
# already_handled_file:yolo_predictions/output18.txt
# already_handled_file:yolo_predictions/output19.txt
# already_handled_file:yolo_predictions/output20.txt
# already_handled_file:yolo_predictions/output21.txt
# already_handled_file:yolo_predictions/output22.txt
# already_handled_file:yolo_predictions/output23.txt
# already_handled_file:yolo_predictions/output24.txt
# already_handled_file:yolo_predictions/output25.txt
# already_handled_file:yolo_predictions/output26.txt
# already_handled_file:yolo_predictions/output27.txt
# already_handled_file:yolo_predictions/output28.txt
# already_handled_file:yolo_predictions/output29.txt
# already_handled_file:yolo_predictions/output30.txt
# already_handled_file:yolo_predictions/output31.txt
# already_handled_file:yolo_predictions/output32.txt
# already_handled_file:yolo_predictions/output33.txt
# already_handled_file:yolo_predictions/output34.txt
# already_handled_file:yolo_predictions/output35.txt
# already_handled_file:yolo_predictions/output36.txt
# already_handled_file:yolo_predictions/output37.txt
# already_handled_file:yolo_predictions/output38.txt
# already_handled_file:yolo_predictions/output39.txt
# already_handled_file:yolo_predictions/output40.txt
# already_handled_file:yolo_predictions/output41.txt
# already_handled_file:yolo_predictions/output42.txt
# already_handled_file:yolo_predictions/output43.txt
# already_handled_file:yolo_predictions/output44.txt
# already_handled_file:yolo_predictions/output45.txt
# already_handled_file:yolo_predictions/output46.txt
# already_handled_file:yolo_predictions/output47.txt
# already_handled_file:yolo_predictions/output48.txt
# already_handled_file:yolo_predictions/output49.txt
# already_handled_file:yolo_predictions/output50.txt
# already_handled_file:yolo_predictions/output51.txt
# already_handled_file:yolo_predictions/output52.txt
# already_handled_file:yolo_predictions/output53.txt
# already_handled_file:yolo_predictions/output54.txt
# already_handled_file:yolo_predictions/output55.txt
# already_handled_file:yolo_predictions/output56.txt
# already_handled_file:yolo_predictions/output57.txt
# already_handled_file:yolo_predictions/output58.txt
# already_handled_file:yolo_predictions/output59.txt
# already_handled_file:yolo_predictions/output60.txt
# already_handled_file:yolo_predictions/output61.txt
# already_handled_file:yolo_predictions/output62.txt
# already_handled_file:yolo_predictions/output63.txt
# already_handled_file:yolo_predictions/output64.txt
# already_handled_file:yolo_predictions/output65.txt
# already_handled_file:yolo_predictions/output66.txt
# already_handled_file:yolo_predictions/output67.txt
# already_handled_file:yolo_predictions/output68.txt
# already_handled_file:yolo_predictions/output69.txt
# already_handled_file:yolo_predictions/output70.txt
# already_handled_file:yolo_predictions/output71.txt
# already_handled_file:yolo_predictions/output72.txt
# already_handled_file:yolo_predictions/output73.txt
# already_handled_file:yolo_predictions/output74.txt
# already_handled_file:yolo_predictions/output75.txt
# already_handled_file:yolo_predictions/output76.txt
# already_handled_file:yolo_predictions/output77.txt
# already_handled_file:yolo_predictions/output78.txt
# already_handled_file:yolo_predictions/output79.txt
# already_handled_file:yolo_predictions/output80.txt
# already_handled_file:yolo_predictions/output81.txt
# already_handled_file:yolo_predictions/output82.txt
# already_handled_file:yolo_predictions/output83.txt
# already_handled_file:yolo_predictions/output84.txt
# already_handled_file:yolo_predictions/output85.txt
# already_handled_file:yolo_predictions/output86.txt
# already_handled_file:yolo_predictions/output87.txt
# already_handled_file:yolo_predictions/output88.txt
# already_handled_file:yolo_predictions/output89.txt
# already_handled_file:yolo_predictions/output90.txt
# already_handled_file:yolo_predictions/output91.txt
# already_handled_file:yolo_predictions/output92.txt
# already_handled_file:yolo_predictions/output93.txt
# already_handled_file:yolo_predictions/output94.txt
# already_handled_file:yolo_predictions/output95.txt
# already_handled_file:yolo_predictions/output96.txt
# already_handled_file:yolo_predictions/output97.txt
# already_handled_file:yolo_predictions/output98.txt
# already_handled_file:yolo_predictions/output99.txt
# already_handled_file:yolo_predictions/output100.txt
# already_handled_file:yolo_predictions/output101.txt
# already_handled_file:yolo_predictions/output102.txt
# already_handled_file:yolo_predictions/output103.txt
# already_handled_file:yolo_predictions/output104.txt
# already_handled_file:yolo_predictions/output105.txt
# already_handled_file:yolo_predictions/output106.txt
# already_handled_file:yolo_predictions/output107.txt
# already_handled_file:yolo_predictions/output108.txt
# already_handled_file:yolo_predictions/output109.txt
# already_handled_file:yolo_predictions/output110.txt
# already_handled_file:yolo_predictions/output111.txt
# already_handled_file:yolo_predictions/output112.txt
# already_handled_file:yolo_predictions/output113.txt
# already_handled_file:yolo_predictions/output114.txt
# already_handled_file:yolo_predictions/output115.txt
# already_handled_file:yolo_predictions/output116.txt
# already_handled_file:yolo_predictions/output117.txt
# already_handled_file:yolo_predictions/output118.txt
# already_handled_file:yolo_predictions/output119.txt
# already_handled_file:yolo_predictions/output120.txt
# already_handled_file:yolo_predictions/output121.txt
# already_handled_file:yolo_predictions/output122.txt
# already_handled_file:yolo_predictions/output123.txt
# already_handled_file:yolo_predictions/output124.txt
# already_handled_file:yolo_predictions/output125.txt
# already_handled_file:yolo_predictions/output126.txt
# already_handled_file:yolo_predictions/output127.txt
# already_handled_file:yolo_predictions/output128.txt
# already_handled_file:yolo_predictions/output129.txt
# already_handled_file:yolo_predictions/output130.txt
# already_handled_file:yolo_predictions/output131.txt
# already_handled_file:yolo_predictions/output132.txt
# already_handled_file:yolo_predictions/output133.txt
# already_handled_file:yolo_predictions/output134.txt
# already_handled_file:yolo_predictions/output135.txt
# already_handled_file:yolo_predictions/output136.txt
# already_handled_file:yolo_predictions/output137.txt
# already_handled_file:yolo_predictions/output138.txt
# already_handled_file:yolo_predictions/output139.txt
# already_handled_file:yolo_predictions/output140.txt
# already_handled_file:yolo_predictions/output141.txt
# already_handled_file:yolo_predictions/output142.txt
# already_handled_file:yolo_predictions/output143.txt
# already_handled_file:yolo_predictions/output144.txt
# already_handled_file:yolo_predictions/output145.txt
# already_handled_file:yolo_predictions/output146.txt
# already_handled_file:yolo_predictions/output147.txt
# already_handled_file:yolo_predictions/output148.txt
# already_handled_file:yolo_predictions/output149.txt
# already_handled_file:yolo_predictions/output150.txt
# already_handled_file:yolo_predictions/output151.txt
# already_handled_file:yolo_predictions/output152.txt
# already_handled_file:yolo_predictions/output153.txt
# already_handled_file:yolo_predictions/output154.txt
# already_handled_file:yolo_predictions/output155.txt
# already_handled_file:yolo_predictions/output156.txt
# already_handled_file:yolo_predictions/output157.txt
# already_handled_file:yolo_predictions/output158.txt
# already_handled_file:yolo_predictions/output159.txt
# already_handled_file:yolo_predictions/output160.txt
# already_handled_file:yolo_predictions/output161.txt
# already_handled_file:yolo_predictions/output162.txt
# already_handled_file:yolo_predictions/output163.txt
# already_handled_file:yolo_predictions/output164.txt
# already_handled_file:yolo_predictions/output165.txt
# already_handled_file:yolo_predictions/output166.txt
# already_handled_file:yolo_predictions/output167.txt
# already_handled_file:yolo_predictions/output168.txt
# already_handled_file:yolo_predictions/output169.txt
# already_handled_file:yolo_predictions/output170.txt
# already_handled_file:yolo_predictions/output171.txt
# already_handled_file:yolo_predictions/output172.txt
# already_handled_file:yolo_predictions/output173.txt
# already_handled_file:yolo_predictions/output174.txt
# already_handled_file:yolo_predictions/output175.txt
# already_handled_file:yolo_predictions/output176.txt
# already_handled_file:yolo_predictions/output177.txt
# already_handled_file:yolo_predictions/output178.txt
# already_handled_file:yolo_predictions/output179.txt
# already_handled_file:yolo_predictions/output180.txt
# already_handled_file:yolo_predictions/output181.txt
# already_handled_file:yolo_predictions/output182.txt
# already_handled_file:yolo_predictions/output183.txt
# already_handled_file:yolo_predictions/output184.txt
# already_handled_file:yolo_predictions/output185.txt
# already_handled_file:yolo_predictions/output186.txt
# already_handled_file:yolo_predictions/output187.txt
# already_handled_file:yolo_predictions/output188.txt
# already_handled_file:yolo_predictions/output189.txt
# already_handled_file:yolo_predictions/output190.txt
# already_handled_file:yolo_predictions/output191.txt
# already_handled_file:yolo_predictions/output192.txt
# already_handled_file:yolo_predictions/output193.txt
# already_handled_file:yolo_predictions/output194.txt
# already_handled_file:yolo_predictions/output195.txt
# already_handled_file:yolo_predictions/output196.txt
# already_handled_file:yolo_predictions/output197.txt
# already_handled_file:yolo_predictions/output198.txt
# already_handled_file:yolo_predictions/output199.txt
# already_handled_file:yolo_predictions/output200.txt
# already_handled_file:yolo_predictions/output201.txt
# already_handled_file:yolo_predictions/output202.txt
# already_handled_file:yolo_predictions/output203.txt
# already_handled_file:yolo_predictions/output204.txt
# already_handled_file:yolo_predictions/output205.txt
# already_handled_file:yolo_predictions/output206.txt
# already_handled_file:yolo_predictions/output207.txt
# already_handled_file:yolo_predictions/output208.txt
# already_handled_file:yolo_predictions/output209.txt
# already_handled_file:yolo_predictions/output210.txt
# already_handled_file:yolo_predictions/output211.txt
# already_handled_file:yolo_predictions/output212.txt
# already_handled_file:yolo_predictions/output213.txt
# already_handled_file:yolo_predictions/output214.txt
# already_handled_file:yolo_predictions/output215.txt
# already_handled_file:yolo_predictions/output216.txt
# already_handled_file:yolo_predictions/output217.txt
# already_handled_file:yolo_predictions/output218.txt
# already_handled_file:yolo_predictions/output219.txt
# already_handled_file:yolo_predictions/output220.txt
# already_handled_file:yolo_predictions/output221.txt
# already_handled_file:yolo_predictions/output222.txt
# already_handled_file:yolo_predictions/output223.txt
# already_handled_file:yolo_predictions/output0.txt
# already_handled_file:yolo_predictions/output1.txt
# already_handled_file:yolo_predictions/output2.txt
# already_handled_file:yolo_predictions/output3.txt
# already_handled_file:yolo_predictions/output4.txt
# already_handled_file:yolo_predictions/output5.txt
# already_handled_file:yolo_predictions/output6.txt
# already_handled_file:yolo_predictions/output7.txt
# already_handled_file:yolo_predictions/output8.txt
# already_handled_file:yolo_predictions/output9.txt
# already_handled_file:yolo_predictions/output10.txt
# already_handled_file:yolo_predictions/output11.txt
# already_handled_file:yolo_predictions/output12.txt
# already_handled_file:yolo_predictions/output13.txt
# already_handled_file:yolo_predictions/output14.txt
# already_handled_file:yolo_predictions/output15.txt
# already_handled_file:yolo_predictions/output16.txt
# already_handled_file:yolo_predictions/output17.txt
# already_handled_file:yolo_predictions/output18.txt
# already_handled_file:yolo_predictions/output19.txt
# already_handled_file:yolo_predictions/output20.txt
# already_handled_file:yolo_predictions/output21.txt
# already_handled_file:yolo_predictions/output22.txt
# already_handled_file:yolo_predictions/output23.txt
# already_handled_file:yolo_predictions/output24.txt
# already_handled_file:yolo_predictions/output25.txt
# already_handled_file:yolo_predictions/output26.txt
# already_handled_file:yolo_predictions/output27.txt
# already_handled_file:yolo_predictions/output28.txt
# already_handled_file:yolo_predictions/output29.txt
# already_handled_file:yolo_predictions/output30.txt
# already_handled_file:yolo_predictions/output31.txt
# already_handled_file:yolo_predictions/output32.txt
# already_handled_file:yolo_predictions/output33.txt
# already_handled_file:yolo_predictions/output34.txt
# already_handled_file:yolo_predictions/output35.txt
# already_handled_file:yolo_predictions/output36.txt
# already_handled_file:yolo_predictions/output37.txt
# already_handled_file:yolo_predictions/output38.txt
# already_handled_file:yolo_predictions/output39.txt
# already_handled_file:yolo_predictions/output40.txt
# already_handled_file:yolo_predictions/output41.txt
# already_handled_file:yolo_predictions/output42.txt
# already_handled_file:yolo_predictions/output43.txt
# already_handled_file:yolo_predictions/output44.txt
# already_handled_file:yolo_predictions/output45.txt
# already_handled_file:yolo_predictions/output46.txt
# already_handled_file:yolo_predictions/output47.txt
# already_handled_file:yolo_predictions/output48.txt
# already_handled_file:yolo_predictions/output49.txt
# already_handled_file:yolo_predictions/output50.txt
# already_handled_file:yolo_predictions/output51.txt
# already_handled_file:yolo_predictions/output52.txt
# already_handled_file:yolo_predictions/output53.txt
# already_handled_file:yolo_predictions/output54.txt
# already_handled_file:yolo_predictions/output55.txt
# already_handled_file:yolo_predictions/output56.txt
# already_handled_file:yolo_predictions/output57.txt
# already_handled_file:yolo_predictions/output58.txt
# already_handled_file:yolo_predictions/output59.txt
# already_handled_file:yolo_predictions/output60.txt
# already_handled_file:yolo_predictions/output61.txt
# already_handled_file:yolo_predictions/output62.txt
# already_handled_file:yolo_predictions/output63.txt
# already_handled_file:yolo_predictions/output64.txt
# already_handled_file:yolo_predictions/output65.txt
# already_handled_file:yolo_predictions/output66.txt
# already_handled_file:yolo_predictions/output67.txt
# already_handled_file:yolo_predictions/output68.txt
# already_handled_file:yolo_predictions/output69.txt
# already_handled_file:yolo_predictions/output70.txt
# already_handled_file:yolo_predictions/output71.txt
# already_handled_file:yolo_predictions/output72.txt
# already_handled_file:yolo_predictions/output73.txt
# already_handled_file:yolo_predictions/output74.txt
# already_handled_file:yolo_predictions/output75.txt
# already_handled_file:yolo_predictions/output76.txt
# already_handled_file:yolo_predictions/output77.txt
# already_handled_file:yolo_predictions/output78.txt
# already_handled_file:yolo_predictions/output79.txt
# already_handled_file:yolo_predictions/output80.txt
# already_handled_file:yolo_predictions/output81.txt
# already_handled_file:yolo_predictions/output82.txt
# already_handled_file:yolo_predictions/output83.txt
# already_handled_file:yolo_predictions/output84.txt
# already_handled_file:yolo_predictions/output85.txt
# already_handled_file:yolo_predictions/output86.txt
# already_handled_file:yolo_predictions/output87.txt
# already_handled_file:yolo_predictions/output88.txt
# already_handled_file:yolo_predictions/output89.txt
# already_handled_file:yolo_predictions/output90.txt
# already_handled_file:yolo_predictions/output91.txt
# already_handled_file:yolo_predictions/output92.txt
# already_handled_file:yolo_predictions/output93.txt
# already_handled_file:yolo_predictions/output94.txt
# already_handled_file:yolo_predictions/output95.txt
# already_handled_file:yolo_predictions/output96.txt
# already_handled_file:yolo_predictions/output97.txt
# already_handled_file:yolo_predictions/output98.txt
# already_handled_file:yolo_predictions/output99.txt
# already_handled_file:yolo_predictions/output100.txt
# already_handled_file:yolo_predictions/output101.txt
# already_handled_file:yolo_predictions/output102.txt
# already_handled_file:yolo_predictions/output103.txt
# already_handled_file:yolo_predictions/output104.txt
# already_handled_file:yolo_predictions/output105.txt
# already_handled_file:yolo_predictions/output106.txt
# already_handled_file:yolo_predictions/output107.txt
# already_handled_file:yolo_predictions/output108.txt
# already_handled_file:yolo_predictions/output109.txt
# already_handled_file:yolo_predictions/output110.txt
# already_handled_file:yolo_predictions/output111.txt
# already_handled_file:yolo_predictions/output112.txt
# already_handled_file:yolo_predictions/output113.txt
# already_handled_file:yolo_predictions/output114.txt
# already_handled_file:yolo_predictions/output115.txt
# already_handled_file:yolo_predictions/output116.txt
# already_handled_file:yolo_predictions/output117.txt
# already_handled_file:yolo_predictions/output118.txt
# already_handled_file:yolo_predictions/output119.txt
# already_handled_file:yolo_predictions/output120.txt
# already_handled_file:yolo_predictions/output121.txt
# already_handled_file:yolo_predictions/output122.txt
# already_handled_file:yolo_predictions/output123.txt
# already_handled_file:yolo_predictions/output124.txt
# already_handled_file:yolo_predictions/output125.txt
# already_handled_file:yolo_predictions/output126.txt
# already_handled_file:yolo_predictions/output127.txt
# already_handled_file:yolo_predictions/output128.txt
# already_handled_file:yolo_predictions/output129.txt
# already_handled_file:yolo_predictions/output130.txt
# already_handled_file:yolo_predictions/output131.txt
# already_handled_file:yolo_predictions/output132.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3b28b3668a2f> in <module>()
#      12         already_handled_file=last_prediction_intime
#      13
# ---> 14 rewrite_html_each(1)
#      15
#      16 #In a command prompt : ./darknet detector demoi darknet.data yolov3-tiny-data.cfg weights/yolov3-tiny-data_final.weights
#
# <ipython-input-9-3b28b3668a2f> in rewrite_html_each(sec)
#       9             print('already_handled_file:'+ str(already_handled_file))
#      10             write_html_code_from_yolo_prediction('Yolo_output_code/index.html',last_prediction_intime)
# ---> 11         time.sleep(sec)
#      12         already_handled_file=last_prediction_intime
#      13
#
# KeyboardInterrupt:

# %%
#check if webcam is working
import cv2
webcam=cv2.VideoCapture(0)
check,frame=webcam.read()
cv2.imshow('frame',frame)
webcam.release()

#cd c:\Program Files\Oracle\VirtualBox
#VBoxManage controlvm "UbuntuProject" webcam attach .1
